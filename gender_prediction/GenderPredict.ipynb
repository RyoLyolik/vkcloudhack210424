# %% [markdown]
# ## Предсказание пола/возраста по посещениям сайтов
#
# Для начала, подключим хранилище s3, содержащее исходные данные:

# %%
# !chmod 600 .s3_passwd
# !mkdir -p mnt
# !s3fs hsevkhack mnt -o url=http://hb.vkcs.cloud -o use_path_request_style -o passwd_file=.s3_passwd -o ro

# %% [markdown]
# Убедимся, что в директории `mnt` содержатся соответствующие таблицы:

# %%
# !ls mnt/
# Out:
# geo_dataframe.csv  requests  train_users.csv

# %% [markdown]
# Если по каким-то причинам директорию смонтировать не удалось, используйте код ниже, чтобы скачать данные к себе в локальное хранилище. В противном случае **пропустите следующую ячейку**.

# %%
import subprocess
# !mkdir -p data
# !wget https://hsehack.hb.ru-msk.vkcs.cloud/geo_dataframe.csv -P data
# !wget https://hsehack.hb.ru-msk.vkcs.cloud/train_users.csv -P data
# !mkdir -p data/requests
for i in range(30):
    print(f"Downloading part {i}...")
    subprocess.call(["wget", f"https://hsehack.hb.ru-msk.vkcs.cloud/requests/part_{i}.parquet", "-q", "-P", "data/requests"])
# Out:
# --2024-04-20 10:30:46--  https://hsehack.hb.ru-msk.vkcs.cloud/geo_dataframe.csv
# Resolving hsehack.hb.ru-msk.vkcs.cloud (hsehack.hb.ru-msk.vkcs.cloud)... 95.163.53.117
# Connecting to hsehack.hb.ru-msk.vkcs.cloud (hsehack.hb.ru-msk.vkcs.cloud)|95.163.53.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63042 (62K) [text/csv]
# Saving to: ‘data/geo_dataframe.csv.1’
#
# geo_dataframe.csv.1 100%[===================>]  61.56K  --.-KB/s    in 0.002s
#
# 2024-04-20 10:30:46 (25.8 MB/s) - ‘data/geo_dataframe.csv.1’ saved [63042/63042]
#
# --2024-04-20 10:30:46--  https://hsehack.hb.ru-msk.vkcs.cloud/train_users.csv
# Resolving hsehack.hb.ru-msk.vkcs.cloud (hsehack.hb.ru-msk.vkcs.cloud)... 95.163.53.117
# Connecting to hsehack.hb.ru-msk.vkcs.cloud (hsehack.hb.ru-msk.vkcs.cloud)|95.163.53.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66826127 (64M) [text/csv]
# Saving to: ‘data/train_users.csv.1’
#
# train_users.csv.1   100%[===================>]  63.73M  53.3MB/s    in 1.2s
#
# 2024-04-20 10:30:48 (53.3 MB/s) - ‘data/train_users.csv.1’ saved [66826127/66826127]
#
# Downloading part 0...
# Downloading part 1...
# Downloading part 2...
# Downloading part 3...
# Downloading part 4...
# Downloading part 5...
# Downloading part 6...
# Downloading part 7...
# Downloading part 8...
# Downloading part 9...
# Downloading part 10...
# Downloading part 11...
# Downloading part 12...
# Downloading part 13...
# Downloading part 14...
# Downloading part 15...
# Downloading part 16...
# Downloading part 17...
# Downloading part 18...
# Downloading part 19...
# Downloading part 20...
# Downloading part 21...
# Downloading part 22...
# Downloading part 23...
# Downloading part 24...
# Downloading part 25...
# Downloading part 26...
# Downloading part 27...
# Downloading part 28...
# Downloading part 29...

# %% [markdown]
# ## Загружаем данные
#
# Используем Pandas для работы с таблицами. `geo_dataframe` содержит данные о геолокации - регионе и стране.

# %%
import pandas as pd
from collections import Counter
from tqdm import tqdm
import numpy as np

from sklearn.model_selection import train_test_split

# %% [markdown]
# Таблица `train_users` - это ваша обучающая выборка, содержащая пол и возраст пользователей. Аналогичная таблица для тестового датасета будет вам предоставлена за час до stop coding.

# %%
users = pd.read_csv('mnt/train_users.csv')
users
# Out:
#           user_id  gender  age
# 0               2       1   61
# 1               3       1   55
# 2               6       0   46
# 3              14       0   66
# 4              17       0   53
# ...           ...     ...  ...
# 4999995  17588859       1   64
# 4999996  17588860       0   69
# 4999997  17588861       1   51
# 4999998  17588864       0   30
# 4999999  17588865       0   38
#
# [5000000 rows x 3 columns]

# %% [markdown]
# Для примера - вот распределение пользователей по полу:

# %% [markdown]
# Основные данные о посещениях пользователями сайтов содержатся в табличке `requests`, представленной в формате parquet. Вы можете загрузить только одну часть таблички, или же всю таблицу, если она поместиться в памяти:

# %%
# from sklearn.neighbors import NearestNeighbors
# from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split

# df = pd.read_parquet('mnt/requests/part_0.parquet')
# req1 = req1.merge(users, left_on='user_id', right_on='user_id')

# le = LabelEncoder()

# le.fit(req1["referer"])
# req1["referer"] = le.transform(req1["referer"])

# le.fit(req1["user_agent"])
# req1["user_agent"] = le.transform(req1["user_agent"])

# for col in req1.columns:
#     req1[col] = req1[col].astype("int")
    
# # X_train, X_test, y_train, y_test = train_test_split(req1.drop(["gender", "age", "user_id"], axis=1), req1[["gender", "age"]], train_size=0.8, stratify=req1[["gender", "age"]])

# # # for col in X_train.columns:
# # #     X_train[col] = (X_train[col] - X_train[col].mean()) / X_train[col].std()
    
# # # for col in X_test.columns:
# # #     X_test[col] = (X_test[col] - X_test[col].mean()) / X_test[col].std()

# # X_train[["gender", "age"]] = y_train
# # X_test[["gender", "age"]] = y_test * 0 - 1

# # nn = NearestNeighbors(n_neighbors=7).fit(X_train)
# # neights = nn.kneighbors(X_test, 15, return_distance=False)

# %%
df = pd.read_parquet("featured/part_0.parquet")
df = df.drop(["timestamp", "user_agent", "referer"], axis=1)

# %%
df.head()
# Out:
#    user_id  gender  age  geo_id region_id country_id  year  month  day  hour  \
# 0        2       1   61     708      7440         40  2024      4    2     0
# 1      251       0   26     708      7440         40  2024      4    1     6
# 2      273       0   33     708      7440         40  2024      4    1    14
# 3      273       0   33     708      7440         40  2024      4    1     1
# 4      273       0   33     708      7440         40  2024      4    1     1
#
#    minute  second  weekday browser_family os_family            brand  \
# 0      21      37        1         Chrome   Android           Huawei
# 1       4      27        0  Chrome Mobile   Android  Generic_Android
# 2      23      12        0  Chrome Mobile   Android  Generic_Android
# 3      56      40        0  Chrome Mobile   Android  Generic_Android
# 4      55      19        0  Chrome Mobile   Android  Generic_Android
#
#   device_type          domain
# 0      mobile     domain_1654
# 1      mobile      domain_381
# 2      mobile      domain_609
# 3      mobile  www.domain_325
# 4      mobile  www.domain_325

# %%
user_features = {
    "domain": 3,
    "device_type": 2,
    "brand": 1,
    "hour": 3,
    "weekday": 2
}

# %%
temp = df[["user_id", "gender", "age", "domain", "device_type", "brand", "hour", "weekday"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 temp = df[["user_id", "gender", "age", "domain", "device_type", "brand", "hour", "weekday"]]
#
# NameError: name 'df' is not defined

# %%
user_featured = users[["user_id", "gender", "age"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 user_featured = users[["user_id", "gender", "age"]]
#
# NameError: name 'users' is not defined

# %%
# for user_feature in tqdm(user_features):
#     grouped = temp.groupby('user_id')[user_feature].apply(list).to_dict()
#     for el in grouped:
#         counts = Counter(grouped[el])
#         grouped_el = sorted(counts, key=lambda x: counts[x], reverse=True)[:5]
#         if len(grouped[el]) < 5:
#             grouped[el] += [np.nan] * (5 - len(grouped[el]))
#     temp_ = pd.DataFrame.from_dict(grouped, orient='index', columns=[f'{user_feature}_top{i}' for i in range(1, user_features[user_feature]+1)])
#     user_featured = user_featured.merge(user_featured, temp_, left_on='user_id', right_index=True)
#     del temp_
#     del grouped
user_features = {
    "domain": 3,
    "device_type": 2,
    "brand": 1,
    "hour": 3,
    "weekday": 2
}
user_featured = users[["user_id", "gender", "age"]]
all_dfs = []
for i in tqdm(range(30)):
    try:
        df = pd.read_parquet(f"featured/part_{i}.parquet")
    except FileNotFoundError: continue
    all_dfs.append(df[["user_id", "gender", "age", "domain", "device_type", "brand", "hour", "weekday"]])

temp = pd.concat(all_dfs)
    
for user_feature in user_features:
    grouped = temp.groupby('user_id')[user_feature].apply(list).to_dict()
    for el in tqdm(grouped):
        counts = Counter(grouped[el])
        grouped_el = sorted(counts, key=lambda x: counts[x], reverse=True)[:user_features[user_feature]]
        if len(grouped[el]) < user_features[user_feature]:
            grouped_el += [np.nan] * (user_features[user_feature] - len(grouped[el]))
        grouped[el] = grouped_el
    columns = [f'{user_feature}_top{i}' for i in range(1, user_features[user_feature]+1)]
    pre = pd.DataFrame.from_dict(grouped, orient='index', columns=columns)
    user_featured = user_featured.merge(pre, left_on='user_id', right_index=True)
# Out:
# 100%|██████████| 30/30 [00:30<00:00,  1.02s/it]
# 100%|██████████| 4468805/4468805 [00:15<00:00, 290847.64it/s]
# 100%|██████████| 4468805/4468805 [00:13<00:00, 321357.94it/s]
# 100%|██████████| 4468805/4468805 [00:13<00:00, 330902.40it/s]
# 100%|██████████| 4468805/4468805 [00:15<00:00, 290718.61it/s]
# 100%|██████████| 4468805/4468805 [00:14<00:00, 313736.04it/s]

# %%
user_featured.to_parquet('4datasets.parquet')

# %%
user_featured = user_featured.replace([None], np.nan)

# %%
user_featured
# Out:
#           user_id  gender  age  domain_top1      domain_top2      domain_top3  \
# 0               2       1   61  domain_1654              NaN              NaN
# 1               3       1   55  domain_2867    www.domain_78              NaN
# 2               6       0   46  domain_3194      domain_1834  www.domain_1123
# 3              14       0   66  domain_2238              NaN              NaN
# 4              17       0   53  domain_2285  www.domain_2582   www.domain_824
# ...           ...     ...  ...          ...              ...              ...
# 4999994  17588855       1   50   domain_145                       domain_3019
# 4999996  17588860       0   69  domain_2238      domain_2042       domain_609
# 4999997  17588861       1   51    domain_21              NaN              NaN
# 4999998  17588864       0   30  domain_2194              NaN              NaN
# 4999999  17588865       0   38  domain_2998              NaN              NaN
#
#         device_type_top1 device_type_top2       brand_top1  hour_top1  \
# 0                 mobile              NaN           Huawei          0
# 1                 mobile              NaN  Generic_Android         15
# 2                 mobile              NaN  Generic_Android         23
# 3                     PC              NaN              NaN         17
# 4                 mobile              NaN  Generic_Android         14
# ...                  ...              ...              ...        ...
# 4999994           mobile              NaN  Generic_Android          0
# 4999996               PC              NaN              NaN          1
# 4999997           mobile              NaN  Generic_Android          5
# 4999998               PC              NaN              NaN          2
# 4999999               PC              NaN              NaN         19
#
#          hour_top2  hour_top3  weekday_top1  weekday_top2
# 0              NaN        NaN             1           NaN
# 1             18.0        NaN             2           1.0
# 2              8.0       19.0             0           1.0
# 3              NaN        NaN             1           NaN
# 4             17.0       15.0             2           NaN
# ...            ...        ...           ...           ...
# 4999994       18.0       13.0             0           2.0
# 4999996       16.0       12.0             1           0.0
# 4999997        NaN        NaN             2           NaN
# 4999998        4.0        6.0             0           1.0
# 4999999        NaN        NaN             2           NaN
#
# [4468805 rows x 14 columns]

# %%
# temp1 = pd.DataFrame.from_dict(grouped_domains, orient='index', columns=['t1', 't2', 't3', 't4', 't5'])

# %%
# ddd = pd.merge(temp, temp1, left_on="user_id", right_index=True)

# %%
# grouped_device_types = temp.groupby('user_id')['device_type'].apply(list).to_dict()
# for el in tqdm(list(grouped_device_types.keys())):
#     counts = Counter(grouped_device_types[el])
#     grouped_device_types[el] = sorted(counts, key=lambda x: counts[x], reverse=True)[:3]
#     if len(grouped_device_types[el]) < 3:
#         grouped_device_types[el] += [np.nan] * (3 - len(grouped_device_types[el]))
# Out:
# 100%|██████████| 2640892/2640892 [00:07<00:00, 365300.77it/s]

# %%
# print(len(temp1), len(grouped_device_types))
# Out:
# 2640892 2640892

# %%
# temp_devices = pd.DataFrame.from_dict(grouped_device_types, orient='index', columns=['device_top1', 'device_top2', 'device_top3'])
# ddd = pd.merge(ddd, temp_devices, left_on='user_id', right_index=True)

# %%
user_featured = user_featured.drop(["user_id"] + list(user_features.keys()), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 user_featured = user_featured.drop(["user_id"] + list(user_features.keys()), axis=1)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
#    5252     errors: IgnoreRaise = "raise",
#    5253 ) -> DataFrame | None:
#    5254     """
#    5255     Drop specified labels from rows or columns.
#    5256
#    (...)
#    5389             weight  1.0     0.8
#    5390     """
# -> 5391     return super().drop(
#    5392         labels=labels,
#    5393         axis=axis,
#    5394         index=index,
#    5395         columns=columns,
#    5396         level=level,
#    5397         inplace=inplace,
#    5398         errors=errors,
#    5399     )
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/generic.py:4510, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508 for axis, labels in axes.items():
#    4509     if labels is not None:
# -> 4510         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4512 if inplace:
#    4513     self._update_inplace(obj)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/generic.py:4551, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4549         new_axis = axis.drop(labels, level=level, errors=errors)
#    4550     else:
# -> 4551         new_axis = axis.drop(labels, errors=errors)
#    4552     indexer = axis.get_indexer(new_axis)
#    4554 # Case for non-unique axis
#    4555 else:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:6972, in Index.drop(self, labels, errors)
#    6970 if mask.any():
#    6971     if errors != "ignore":
# -> 6972         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973     indexer = indexer[~mask]
#    6974 return self.delete(indexer)
#
# KeyError: "['domain', 'device_type', 'brand', 'hour', 'weekday'] not found in axis"

# %%
user_featured

# %%
X_train, X_test, y_train, y_test = train_test_split(user_featured.drop(["gender", "age"], axis=1), user_featured[["gender", "age"]], train_size=0.8, stratify=user_featured["gender"])

# %%
X_train
# Out:
#           user_id      domain_top1     domain_top2 domain_top3  \
# 2076935   7279826  www.domain_1707             NaN         NaN
# 3621540  12728891      domain_1654             NaN         NaN
# 728020    2549944      domain_2194            None        None
# 4313062  15174688      domain_1406  www.domain_403        None
# 4021267  14143791      domain_2238             NaN         NaN
# ...           ...              ...             ...         ...
# 1888168   6677767        domain_11             NaN         NaN
# 4955815  17399069      domain_1180             NaN         NaN
# 4812317  16917419       domain_609             NaN         NaN
# 675966    2357748      domain_3357             NaN         NaN
# 2084329   7309220      domain_1418     domain_2402        None
#
#         device_type_top1 device_type_top2       brand_top1  hour_top1  \
# 2076935               PC              NaN             None         12
# 3621540           mobile              NaN          Samsung          3
# 728020                PC             None             None          5
# 4313062               PC             None             None          4
# 4021267               PC              NaN             None         10
# ...                  ...              ...              ...        ...
# 1888168               PC              NaN             None         15
# 4955815               PC              NaN             None          8
# 4812317               PC              NaN             None          9
# 675966            mobile              NaN          Samsung         13
# 2084329           mobile             None  Generic_Android         11
#
#          hour_top2  hour_top3  weekday_top1  weekday_top2
# 2076935        NaN        NaN             2           NaN
# 3621540        NaN        NaN             2           NaN
# 728020        15.0        NaN             1           2.0
# 4313062        NaN        NaN             2           NaN
# 4021267        NaN        NaN             0           NaN
# ...            ...        ...           ...           ...
# 1888168        NaN        NaN             0           NaN
# 4955815        NaN        NaN             0           NaN
# 4812317        NaN        NaN             0           NaN
# 675966         NaN        NaN             1           NaN
# 2084329        9.0       13.0             2           0.0
#
# [2244758 rows x 12 columns]

# %%
from tqdm import tqdm

pred_gender = []
pred_age = []

for a in tqdm(neights[:50000]):
    temp = X_train.iloc[a].groupby("gender").agg({"gender": "count", "age": "mean"})
    pred_gender.append(temp[temp["gender"] == temp["gender"].max()].index[0])
    pred_age.append(temp[temp["gender"] == temp["gender"].max()].age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3 pred_gender = []
#       4 pred_age = []
# ----> 6 for a in tqdm(neights[:50000]):
#       7     temp = X_train.iloc[a].groupby("gender").agg({"gender": "count", "age": "mean"})
#       8     pred_gender.append(temp[temp["gender"] == temp["gender"].max()].index[0])
#
# NameError: name 'neights' is not defined

# %% [markdown]
# ## Дерзайте!
#
# Вам необходимо построить предсказательную модель для прогнозирования пола и возраста пользователей по их посещениям. Таблица с тестовыми пользователями будет предоставлена вам за час до stop coding.
#
# ВАЖНО:
# * Таблицу с тестовыми данными нельзя использовать для обучения модели. Если жюри увидит, что вы использовали табличку с тестовыми данными - точность модели будет оцениваться в 0 баллов.
# * В ходе выступления необходимо продемонстрировать точность модели на тестовых данных.

# %% [markdown]
# ### Установка библиотек

# %%
X_train
# Out:
#           domain_top1  domain_top2      domain_top3 domain_top4 domain_top5  \
# 567788    domain_1081  domain_2042       domain_609        None        None
# 11544885  domain_2998   domain_609              nan        None        None
# 2244153   domain_2206   domain_609             None        None        None
# 10265454   domain_609          nan             None        None        None
# 10077815  domain_2042  domain_2206             None        None        None
# ...               ...          ...              ...         ...         ...
# 8874200   domain_2194         None             None        None        None
# 3774263   domain_2042   domain_609  www.domain_2395        None        None
# 5814635   domain_2194  domain_2206      domain_1180  domain_390  domain_573
# 7882427   domain_2042  domain_1081       domain_609        None        None
# 3993120   domain_1654          nan              nan         nan         nan
#
#          device_type_top1 device_type_top2 device_type_top3       brand_top1  \
# 567788                 PC             None             None             None
# 11544885               PC             None             None             None
# 2244153                PC             None             None             None
# 10265454               PC             None             None             None
# 10077815               PC             None             None             None
# ...                   ...              ...              ...              ...
# 8874200                PC             None             None             None
# 3774263            mobile             None             None  Generic_Android
# 5814635                PC             None             None             None
# 7882427                PC             None             None             None
# 3993120            mobile              nan              nan  Generic_Android
#
#          brand_top2 hour_top1 hour_top2 hour_top3 hour_top4 hour_top5  \
# 567788         None        12       8.0       nan       nan       nan
# 11544885       None         8       nan       nan       nan       nan
# 2244153        None         7      12.0      10.0       nan       nan
# 10265454       None        10       nan       nan       nan       nan
# 10077815       None         8      11.0       nan       nan       nan
# ...             ...       ...       ...       ...       ...       ...
# 8874200        None        11      10.0       nan       nan       nan
# 3774263        None         6       4.0       7.0       5.0       nan
# 5814635        None        21       9.0      23.0      16.0       nan
# 7882427        None        14      19.0       nan       nan       nan
# 3993120         nan         3       nan       nan       nan       nan
#
#          hour_top6 hour_top7 weekday_top1 weekday_top2 weekday_top3
# 567788         nan       nan            2          0.0          nan
# 11544885       nan       nan            2          nan          nan
# 2244153        nan       nan            0          1.0          nan
# 10265454       nan       nan            0          nan          nan
# 10077815       nan       nan            2          1.0          nan
# ...            ...       ...          ...          ...          ...
# 8874200        nan       nan            2          nan          nan
# 3774263        nan       nan            1          0.0          nan
# 5814635        nan       nan            6          0.0          1.0
# 7882427        nan       nan            2          1.0          nan
# 3993120        nan       nan            2          nan          nan
#
# [9725928 rows x 20 columns]

# %%
from catboost import CatBoostClassifier
cat_cols = []
for user_feature in user_features:
    for n in range(1, user_features[user_feature]+1):
        cat_cols.append(f'{user_feature}_top{n}')


for c in X_train.columns:
    X_train[c] = X_train[c].astype("str")
    X_test[c]  = X_test[c].astype("str")

cat = CatBoostClassifier(iterations=100, learning_rate=0.997, depth=7, cat_features=cat_cols)

cat.fit(X_train, y_train["gender"], eval_set=(X_test, y_test["gender"]), verbose=10)
# Out:
# 0:	learn: 0.6560463	test: 0.6558102	best: 0.6558102 (0)	total: 520ms	remaining: 51.5s
# 10:	learn: 0.6375161	test: 0.6371301	best: 0.6371301 (10)	total: 4.25s	remaining: 34.4s
# 20:	learn: 0.6363484	test: 0.6359639	best: 0.6359639 (20)	total: 7.71s	remaining: 29s
# 30:	learn: 0.6359353	test: 0.6356588	best: 0.6356588 (30)	total: 11.1s	remaining: 24.6s
# 40:	learn: 0.6357550	test: 0.6355643	best: 0.6355643 (40)	total: 14.4s	remaining: 20.7s
# 50:	learn: 0.6355897	test: 0.6354326	best: 0.6354319 (49)	total: 18.1s	remaining: 17.4s
# 60:	learn: 0.6354370	test: 0.6353438	best: 0.6353438 (60)	total: 23.6s	remaining: 15.1s
# 70:	learn: 0.6353458	test: 0.6353396	best: 0.6353396 (70)	total: 29s	remaining: 11.8s
# 80:	learn: 0.6352551	test: 0.6353108	best: 0.6353108 (80)	total: 34.5s	remaining: 8.1s
# 90:	learn: 0.6352099	test: 0.6353211	best: 0.6353104 (81)	total: 38.4s	remaining: 3.8s
# 99:	learn: 0.6351471	test: 0.6353001	best: 0.6352992 (98)	total: 41.3s	remaining: 0us
#
# bestTest = 0.6352991541
# bestIteration = 98
#
# Shrink model to first 99 iterations.

# %%
cat.get_feature_importance(prettified=True)
# Out:
#           Feature Id  Importances
# 0        domain_top1    38.748966
# 1        domain_top2    29.422937
# 2        domain_top3    14.319666
# 3         brand_top1     9.341919
# 4          hour_top3     2.177810
# 5          hour_top1     2.111354
# 6          hour_top2     1.427463
# 7   device_type_top2     1.150699
# 8       weekday_top2     0.357017
# 9   device_type_top1     0.327036
# 10           user_id     0.321757
# 11      weekday_top1     0.293377

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test["gender"], cat.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.57      0.60    443726
#            1       0.61      0.68      0.64    450035
#
#     accuracy                           0.62    893761
#    macro avg       0.62      0.62      0.62    893761
# weighted avg       0.62      0.62      0.62    893761

# %% [markdown]
# ## Убираем за собой
#
# В конце работы можем размонтировать директорию:

# %%
# !umount mnt
# Out:
# umount: /home/datadisk/jupyter-vkhack/vkhack/gender_prediction/mnt: not mounted.
